# %% [markdown]
# <a href="https://colab.research.google.com/github/juccalle/CAP4630/blob/master/HW1/Assignment1Part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
import numpy as np
np.random.seed(42)

xs = 2 * np.random.rand(100, 1)
xTwos = 2 * np.random.rand(100, 1)
ys = 4 + 3 * xs + np.random.rand(100, 1)

# %%
# plt.plot(xs, ys, "b.")
# plt.xlabel("$x_1$", fontsize=18)
# plt.ylabel("$y$", rotation=0, fontsize=18)
# plt.axis([0, 2, 0, 15])
# plt.show()
ax = plt.axes(projection='3d')

ax.scatter3D(xs, xTwos, ys)

# %%
# split the data into training and test sets
# train set
train_xs = xs[:80]
train_xTwos = xTwos[:80]
train_ys = ys[:80]
# test set
test_xs = xs[80:]
test_xTwos = xTwos[80:]
test_ys = ys[80:]

# %% [markdown]
# # Linear regression using numpy

# %%
# number of epochs
epochs = 10
# learning rate
lr = 0.01

# %%
# initial value for weight w and bias b
w = np.random.randn(1)
wTwo = np.random.randn(1)
b = np.zeros(1)

# %%
for epoch in np.arange(epochs):
  for i in np.arange(80):
    y_pred = w * train_xs[i] + wTwo * train_xTwos[i] + b
    
    gradwOne = (y_pred - train_ys[i]) * train_xs[i]
    gradwTwo = (y_pred - train_ys[i]) * train_xTwos[i]
    grad_b = (y_pred - train_ys[i])
    
    w -= lr * gradwOne
    wTwo -= lr * gradwTwo
    b -= lr * grad_b

# %%
test_loss = 0
for i in np.arange(20):
  test_loss += 0.5 * (w * test_xs[i] + b - test_ys[i]) ** 2
test_loss /= 20

# %%
test_loss
# Out:
# array([0.05016281])

# %%
pred_ys = w * test_xs + wTwo * test_xTwos + b

# %%
# plt.plot(test_xs, test_ys, "b.")
# plt.plot(test_xs, pred_ys, "r.") # predicted values
# plt.xlabel("$x_1$", fontsize=18)
# plt.ylabel("$y$", rotation=0, fontsize=18)
# plt.axis([0, 2, 0, 15])
# plt.show()

ax = plt.axes(projection='3d')

zdata = test_ys
xdata = test_xs
ydata = test_xTwos

ax.scatter3D(xdata, ydata, zdata)
ax.scatter3D(xdata, ydata, pred_ys)

# %%
b
# Out:
# array([3.836611])

# %%
w
# Out:
# array([3.25855477])
