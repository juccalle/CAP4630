# %% [markdown]
# <a href="https://colab.research.google.com/github/juccalle/CAP4630/blob/master/HW4/Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **General Concepts:**
#
# AI:
#
# The branch of science that involves the use of computers in order to perform task normally done by humans. In modern cases computers are used to emulate human actions. This could be visual, medicinal and many more.
#
# Machine Learning:
#
# A form of data analysis that concerns itself with building algorithms that can learn from data. Machine learning stems from AI.
#
# Deep Learning:
#
# A further deviation from Machine Learning that involves programs being able to learn without or with the need of supervision.
#
# Gradient Descent:
#
# Algorithm used in order to to optimize. In our course it was used to optimize parmeters.
#
# **Building Model:**
#
# Conv2D:
#
# Conv2D is a 2D Convolution Layer, this layer creates a convolution kernel that is convolved with layers input which helps produce a tensor of outputs.
#
# Strides:
#
# Strides are essentially the spacing between uses of convolutional filters.
#
# Kernel Size:
#
# This is the size of the filter that is being utilized.
#
# Padding:
#
# Padding is a term relevant to convolutional neural networks as it refers to the amount of pixels added to an image when it is being processed by the kernel of a CNN.
#
# MaxPooling:
#
# This is the process of "scaling" down an image being used.
#
# Dense Layers:
#
#  A linear operation on the layer’s input vector.
#
#  Softmax:
#
#  Normalizes a vector into a probability distribution.
#
#  Sigmoid:
#
#  A function that is an S shaped graph.
#
#  RELU:
#
#  f(x) = max(0, x)
#
#  LeakyRELU:
#
#  f(x) = max(0.01x, x)
#
#  tanh:
#
#  f(x) = tanh(x)
#
#  **Compiling:**
#
# List of Optimizers:
#     Adagrad
#     RMSProp
#     ADAM
#
#   The purpose of these optimizers is to either minimize or maximize an objective function.
#
#   Regression Problem:
#   when the output variable is a real or continuous value like age and height.
#
# Binary Classification Problem:
#
# Being able to decide between to seperate groups. The image is either group 0 or group 1.
#
# Multi-Class Classification Problem:
#
# This is the opposite of Binary. You categorize in more than 2 groups.
#
# Metric:
#
# Its a function that helps determine how well the model developed works in practice. Is it identifying correctly? or is it folding?
#
# Learning Rate:
#
# The amount that the weights are updated during training.
#
# **Training:**
#
# Overfit:
#
# A modeling error that occurs when a function is too closely fit to a limited set of data points
#
# Underfit:
#
# An error that occurs when the model is not complex enough to properly complete its job.
#
#
#
# **Finetune:**
#
# This is the process of using a model that has been used an resuing it again.

# %%
# Plot the first X test images, their predicted label, and the true label
# Color correct predictions in blue, incorrect predictions in red
# trying to plot results
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions, test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions, test_labels)

# %%
# using Conv2d and softmax

model = keras.Sequential([
    keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)), 
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# %%
#example of using optimizer Adam

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# train the model
epochs = 30
history = model.fit(train_images, 
                      train_labels, 
                      epochs=epochs,  
                      validation_data=(test_images, test_labels))
